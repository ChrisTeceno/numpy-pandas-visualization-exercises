# %%
import matplotlib.pyplot as plt 
from numpy import linspace

from math import sqrt

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y=x^2−x+2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = list(range(-10, 10))
y = [n**2 - n+2 for n in x]
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('A Quadratic Distribution, $y = x^2 - x+2$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$x^2- x+2$', c='white')
plt.text(0.25, 0, '(0, 0)', fontsize=20, color='red')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y=√x
#
# y=x^3
#
# y=2^x
#
# y=1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
# y=√x
x = list(range(0, 100))
y = [(sqrt(n)) for n in x]
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=√x$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$√x$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()

# %%
# y=x^3
x = list(range(-100, 100))
y = [n**3 for n in x]
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=x^3$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$x^3$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()

# %%
#y=2^x
x = list(range(-10, 10))
y = [2**n for n in x]
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=2^x$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$2^x$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()

# %%
#y=1/(x+1)
x = list(range(0, 100))
y = [1/(n+1) for n in x]
plt.plot(x,y)
x = list(range(-100, -2))
y = [1/(n+1) for n in x]
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=1/(x+1)$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$1/(x+1)$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
# y=√x
x = list(range(0, 100))
y = [(sqrt(n)) for n in x]
plt.subplot(2,2,1)
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=√x$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$√x$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
# y=x^3
x = list(range(-100, 100))
y = [n**3 for n in x]
plt.subplot(2,2,2)
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=x^3$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$x^3$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
#y=2^x
x = list(range(-10, 10))
y = [2**n for n in x]
plt.subplot(2,2,3)
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=2^x$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$2^x$', c='white')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
#y=1/(x+1)
x = list(range(0, 100))
y = [1/(n+1) for n in x]
plt.subplot(2,2,4)
plt.plot(x,y)
x = list(range(-100, -2))
y = [1/(n+1) for n in x]
plt.subplot(2,2,4)
plt.plot(x,y)
plt.plot(0,0, marker = 'o')
plt.title('$y=1/(x+1)$', c='white')
plt.xlabel('$x$', c='white')
plt.ylabel('$1/(x+1)$', c='white')

plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
# y=√x
x1 = list(range(0, 15))
y1 = [sqrt(n) for n in x1]
plt.plot(x1,y1, c = 'red', label = '$y=√x$')
plt.plot(0,0, marker = 'o')

#y=x^3
x2 = list (linspace(-10,10, num = 1000))
y2 = [n**3 for n in x2]
plt.plot(x2,y2, c = 'blue', label = '$y=x^3$')

#y=2^x
x3 = list (linspace(-10,10, num = 1000))
y3 = [2**n for n in x3]
plt.plot(x3,y3, c = 'black', label = '$y=2^x$')

#y=1/(x+1)
x4 = list (linspace(-1,10, num = 10000))
x4.remove(-1.0)
y4 = [1/(n+1) for n in x4]
plt.plot(x4,y4, c = 'green', label = '$y=1/(x+1)$')
x4 = list (linspace(-10,-1, num = 10000))
x4.remove(-1.0)
y4 = [1/(n+1) for n in x4]
plt.plot(x4,y4, c = 'green')



font1 = {'family':'serif','color':'white','size':20}
plt.title('Combination of functions',  fontdict= font1)
plt.xlabel("x", fontdict= font1)
plt.ylabel("y", fontdict= font1)
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.legend(loc='lower right')
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.savefig('combinations-of-functions')
plt.show()

# %% [markdown]
# 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# Title your chart "Big O Notation"
# Label your x axis "Elements"
# Label your y axis "Operations"
# Label your curves or make a legend for the curves
# Use LaTex notation where possible
# Curves to graph
#
# y=0n+1 and label the curve "O(1)"
#
# y=log(n) and label the curve "O(log n)"
#
# y=n and label the curve "O(n)"
#
# y=n∗log(n) and label it "O(n log n)"
#
# y=n^2 and label it "O(n^2)"
#
# y=2^n and label it "O(2^n)"
#
# y=n! and label it "O(n!)"
#
# y=n^n and label it "O(n^n)"

# %% [markdown]
# 6. Bonus Write the code necessary to write your name on a chart. Use box letters.

# %%
x1= [15, 20, 10, 10, 20, 15]
y1= [15, 15, 15, 85, 85, 85]
x2= [35, 35, 35, 35, 50, 50, 50]
y2= [45, 85,15, 45, 45, 15, 25]
x3=[65,65,65,70,75,80,75,70,65]
y3=[45,15,40,40,45,45,45,40,40]
x4=[95,95,95]
y4=[35,15,45]
x5=[115,110,120,130,110,120,130,125]
y5=[20,25,15,25,40,45,40,42.5]
plt.plot(x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, linewidth = '20')
plt.plot(95, 60,marker = 'o', c='red', ms= '20')

font1 = {'family':'serif','color':'white','size':40}
plt.title('My name',  fontdict= font1)
plt.xlim(0, 150)
plt.ylim(0, 100) 
plt.savefig('my-name')
plt.show()

# %% [markdown]
# 7. Bonus: use curves for letters in your name that have curves in them.

# %%
x1= list (linspace(0, 10, num = 1000))
y1= [10*sqrt(n)*0.5 for n in x1]
y2= [-10*sqrt(n)*0.5 for n in x1]
x3=[15,15]
y3=[-17,17]
x4=list (range(15,26))
y4=[-0.7*((n-20)**2) for n in x4]
x5=[30,30]
y5=[-17,0]
x6=list (range(30,37))
y6=[-0.7*((n-35)**2) for n in x6]
x7=[40,40]
y7=[-17,0]
x8=[40,40]
y8=[5,7]
x9= list (linspace(45, 55, num = 1000))
y9= [10*sqrt(n)*0.15-5 for n in x1]
x10= list (linspace(45, 50, num = 1000))
y10= [-10*sqrt(n)*0.11-5 for n in x1]
x11= list (linspace(50, 55, num = 1000))
x11b=list (linspace(-10, 0, num = 1000))
y11= [10*sqrt(-n)*0.11-12 for n in x11b]
y12= [-10*sqrt(-n)*0.15-12 for n in x11b]

plt.plot(x1, y1, x1, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10,y10, x11, y11,x9,y12, linewidth = '10')

font1 = {'family':'serif','color':'white','size':40}
plt.title('My name',  fontdict= font1)
# plt.xlim(-10, 150)
# plt.ylim(-100, 100) 
plt.savefig('my-name2')
plt.tick_params(axis='x', colors='w')
plt.tick_params(axis='y', colors='w')
plt.show()
